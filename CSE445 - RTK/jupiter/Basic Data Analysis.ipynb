# %% [markdown]
# # Data Pre-processing
#
#  - Read the dataset

# %%
# import pandas
import pandas as pd # pd is an alias of pandas

# %%
#Read the dataset and store it in a dataframe
df = pd.read_excel('Absenteeism.xls')
# df = pd.read_excel('Absenteeism.xls',nrows = 500) # read the first 500 rows of the dataset

# %%
# settings to display all columns
pd.set_option("display.max_columns", None)
#print the shape of the dataframe; Return a tuple representing the dimensionality of the DataFrame.
#tells the number of rows and columns of a given DataFrame
print("Shape of the dataset", df.shape)
df.shape
# tuple: store multiple items; written with round brackets
#df.head() # print the first 5 instances and
# Out:
# Shape of the dataset (740, 21)
# Shape of the dataset (740, 21)
# (740, 21)
# (740, 21)

# %%
#printing number of rows and number of columns
print('Number of rows: ', df.shape[0])
print('Number of columns: ', df.shape[1])
# Out:
# Number of rows:  740
# Number of columns:  21
# Number of rows:  740
# Number of columns:  21

# %%
#prints all the column names; columns is an attribute NOT a method/function
print(df.columns)
#df.columns.tolist()
#print(df.columns.tolist())
# Out:
# Index(['ID', 'Reason for absence', 'Month of absence', 'Day of the week',
#        'Seasons', 'Transportation expense', 'Distance from Residence to Work',
#        'Service time', 'Age', 'Work load Average/day ', 'Hit target',
#        'Disciplinary failure', 'Education', 'Son', 'Social drinker',
#        'Social smoker', 'Pet', 'Weight', 'Height', 'Body mass index',
#        'Absenteeism time in hours'],
#       dtype='object')
# Index(['ID', 'Reason for absence', 'Month of absence', 'Day of the week',
#        'Seasons', 'Transportation expense', 'Distance from Residence to Work',
#        'Service time', 'Age', 'Work load Average/day ', 'Hit target',
#        'Disciplinary failure', 'Education', 'Son', 'Social drinker',
#        'Social smoker', 'Pet', 'Weight', 'Height', 'Body mass index',
#        'Absenteeism time in hours'],
#       dtype='object')

# %%
# Example of some attributes
df.dtypes # data types of ALL the features
# Out:
# ID                                   int64
# Reason for absence                 float64
# Month of absence                   float64
# Day of the week                      int64
# Seasons                              int64
# Transportation expense             float64
# Distance from Residence to Work    float64
# Service time                       float64
# Age                                float64
# Work load Average/day              float64
# Hit target                         float64
# Disciplinary failure               float64
# Education                          float64
# Son                                float64
# Social drinker                     float64
# Social smoker                      float64
# Pet                                float64
# Weight                             float64
# Height                             float64
# Body mass index                    float64
# Absenteeism time in hours          float64
# dtype: object
# ID                                   int64
# Reason for absence                 float64
# Month of absence                   float64
# Day of the week                      int64
# Seasons                              int64
# Transportation expense             float64
# Distance from Residence to Work    float64
# Service time                       float64
# Age                                float64
# Work load Average/day              float64
# Hit target                         float64
# Disciplinary failure               float64
# Education                          float64
# Son                                float64
# Social drinker                     float64
# Social smoker                      float64
# Pet                                float64
# Weight                             float64
# Height                             float64
# Body mass index                    float64
# Absenteeism time in hours          float64
# dtype: object

# %%
df.ndim # prints dimension of the dataset
# Out:
# 2
# 2

# %%
df.size # number of total elements in the dataset; 715 \times 21
# Out:
# 15540
# 15540

# %%
#printing the column names in the form of a list
col_list = [] # this is an empty list
for x in df.columns:
    col_list.append(x)
print(col_list)
col_list
# Out:
# ['ID', 'Reason for absence', 'Month of absence', 'Day of the week', 'Seasons', 'Transportation expense', 'Distance from Residence to Work', 'Service time', 'Age', 'Work load Average/day ', 'Hit target', 'Disciplinary failure', 'Education', 'Son', 'Social drinker', 'Social smoker', 'Pet', 'Weight', 'Height', 'Body mass index', 'Absenteeism time in hours']
# ['ID', 'Reason for absence', 'Month of absence', 'Day of the week', 'Seasons', 'Transportation expense', 'Distance from Residence to Work', 'Service time', 'Age', 'Work load Average/day ', 'Hit target', 'Disciplinary failure', 'Education', 'Son', 'Social drinker', 'Social smoker', 'Pet', 'Weight', 'Height', 'Body mass index', 'Absenteeism time in hours']
# ['ID',
#  'Reason for absence',
#  'Month of absence',
#  'Day of the week',
#  'Seasons',
#  'Transportation expense',
#  'Distance from Residence to Work',
#  'Service time',
#  'Age',
#  'Work load Average/day ',
#  'Hit target',
#  'Disciplinary failure',
#  'Education',
#  'Son',
#  'Social drinker',
#  'Social smoker',
#  'Pet',
#  'Weight',
#  'Height',
#  'Body mass index',
#  'Absenteeism time in hours']
# ['ID',
#  'Reason for absence',
#  'Month of absence',
#  'Day of the week',
#  'Seasons',
#  'Transportation expense',
#  'Distance from Residence to Work',
#  'Service time',
#  'Age',
#  'Work load Average/day ',
#  'Hit target',
#  'Disciplinary failure',
#  'Education',
#  'Son',
#  'Social drinker',
#  'Social smoker',
#  'Pet',
#  'Weight',
#  'Height',
#  'Body mass index',
#  'Absenteeism time in hours']

# %%
# printing Basic infos (Non-null count and data type) per feature of the dataset
print(df.info());
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 740 entries, 0 to 739
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ID                               740 non-null    int64
#  1   Reason for absence               737 non-null    float64
#  2   Month of absence                 739 non-null    float64
#  3   Day of the week                  740 non-null    int64
#  4   Seasons                          740 non-null    int64
#  5   Transportation expense           733 non-null    float64
#  6   Distance from Residence to Work  737 non-null    float64
#  7   Service time                     737 non-null    float64
#  8   Age                              737 non-null    float64
#  9   Work load Average/day            730 non-null    float64
#  10  Hit target                       734 non-null    float64
#  11  Disciplinary failure             734 non-null    float64
#  12  Education                        730 non-null    float64
#  13  Son                              734 non-null    float64
#  14  Social drinker                   737 non-null    float64
#  15  Social smoker                    736 non-null    float64
#  16  Pet                              738 non-null    float64
#  17  Weight                           739 non-null    float64
#  18  Height                           726 non-null    float64
#  19  Body mass index                  709 non-null    float64
#  20  Absenteeism time in hours        718 non-null    float64
# dtypes: float64(18), int64(3)
# memory usage: 121.5 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 740 entries, 0 to 739
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ID                               740 non-null    int64
#  1   Reason for absence               737 non-null    float64
#  2   Month of absence                 739 non-null    float64
#  3   Day of the week                  740 non-null    int64
#  4   Seasons                          740 non-null    int64
#  5   Transportation expense           733 non-null    float64
#  6   Distance from Residence to Work  737 non-null    float64
#  7   Service time                     737 non-null    float64
#  8   Age                              737 non-null    float64
#  9   Work load Average/day            730 non-null    float64
#  10  Hit target                       734 non-null    float64
#  11  Disciplinary failure             734 non-null    float64
#  12  Education                        730 non-null    float64
#  13  Son                              734 non-null    float64
#  14  Social drinker                   737 non-null    float64
#  15  Social smoker                    736 non-null    float64
#  16  Pet                              738 non-null    float64
#  17  Weight                           739 non-null    float64
#  18  Height                           726 non-null    float64
#  19  Body mass index                  709 non-null    float64
#  20  Absenteeism time in hours        718 non-null    float64
# dtypes: float64(18), int64(3)
# memory usage: 121.5 KB
# None

# %%
#printing basic statistical infos per feature of the dataset
df.describe()
# Out:
#                ID  Reason for absence  Month of absence  Day of the week  \
# count  740.000000          737.000000        739.000000       740.000000
# mean    18.017568           19.188602          6.319350         3.914865
# std     11.021247            8.437493          3.435948         1.421675
# min      1.000000            0.000000          0.000000         2.000000
# 25%      9.000000           13.000000          3.000000         3.000000
# 50%     18.000000           23.000000          6.000000         4.000000
# 75%     28.000000           26.000000          9.000000         5.000000
# max     36.000000           28.000000         12.000000         6.000000
#
#           Seasons  Transportation expense  Distance from Residence to Work  \
# count  740.000000              733.000000                       737.000000
# mean     2.544595              221.035471                        29.667571
# std      1.111831               66.954179                        14.848124
# min      1.000000              118.000000                         5.000000
# 25%      2.000000              179.000000                        16.000000
# 50%      3.000000              225.000000                        26.000000
# 75%      4.000000              260.000000                        50.000000
# max      4.000000              388.000000                        52.000000
#
#        Service time         Age  Work load Average/day   Hit target  \
# count    737.000000  737.000000              730.000000  734.000000
# mean      12.565807   36.449118           271188.860274   94.587193
# std        4.389813    6.480148            38981.880873    3.792705
# min        1.000000   27.000000           205917.000000   81.000000
# 25%        9.000000   31.000000           244387.000000   93.000000
# 50%       13.000000   37.000000           264249.000000   95.000000
# 75%       16.000000   40.000000           284853.000000   97.000000
# max       29.000000   58.000000           378884.000000  100.000000
#
#        Disciplinary failure   Education         Son  Social drinker  \
# count            734.000000  730.000000  734.000000      737.000000
# mean               0.053134    1.295890    1.017711        0.567164
# std                0.224453    0.676965    1.094928        0.495805
# min                0.000000    1.000000    0.000000        0.000000
# 25%                0.000000    1.000000    0.000000        0.000000
# 50%                0.000000    1.000000    1.000000        1.000000
# 75%                0.000000    1.000000    2.000000        1.000000
# max                1.000000    4.000000    4.000000        1.000000
#
#        Social smoker         Pet      Weight      Height  Body mass index  \
# count     736.000000  738.000000  739.000000  726.000000       709.000000
# mean        0.073370    0.746612   79.063599  172.152893        26.684062
# std         0.260919    1.319726   12.868630    6.081065         4.292819
# min         0.000000    0.000000   56.000000  163.000000        19.000000
# 25%         0.000000    0.000000   69.000000  169.000000        24.000000
# 50%         0.000000    0.000000   83.000000  170.000000        25.000000
# 75%         0.000000    1.000000   89.000000  172.000000        31.000000
# max         1.000000    8.000000  108.000000  196.000000        38.000000
#
#        Absenteeism time in hours
# count                 718.000000
# mean                    6.977716
# std                    13.476962
# min                     0.000000
# 25%                     2.000000
# 50%                     3.000000
# 75%                     8.000000
# max                   120.000000
#                ID  Reason for absence  Month of absence  Day of the week  \
# count  740.000000          737.000000        739.000000       740.000000
# mean    18.017568           19.188602          6.319350         3.914865
# std     11.021247            8.437493          3.435948         1.421675
# min      1.000000            0.000000          0.000000         2.000000
# 25%      9.000000           13.000000          3.000000         3.000000
# 50%     18.000000           23.000000          6.000000         4.000000
# 75%     28.000000           26.000000          9.000000         5.000000
# max     36.000000           28.000000         12.000000         6.000000
#
#           Seasons  Transportation expense  Distance from Residence to Work  \
# count  740.000000              733.000000                       737.000000
# mean     2.544595              221.035471                        29.667571
# std      1.111831               66.954179                        14.848124
# min      1.000000              118.000000                         5.000000
# 25%      2.000000              179.000000                        16.000000
# 50%      3.000000              225.000000                        26.000000
# 75%      4.000000              260.000000                        50.000000
# max      4.000000              388.000000                        52.000000
#
#        Service time         Age  Work load Average/day   Hit target  \
# count    737.000000  737.000000              730.000000  734.000000
# mean      12.565807   36.449118           271188.860274   94.587193
# std        4.389813    6.480148            38981.880873    3.792705
# min        1.000000   27.000000           205917.000000   81.000000
# 25%        9.000000   31.000000           244387.000000   93.000000
# 50%       13.000000   37.000000           264249.000000   95.000000
# 75%       16.000000   40.000000           284853.000000   97.000000
# max       29.000000   58.000000           378884.000000  100.000000
#
#        Disciplinary failure   Education         Son  Social drinker  \
# count            734.000000  730.000000  734.000000      737.000000
# mean               0.053134    1.295890    1.017711        0.567164
# std                0.224453    0.676965    1.094928        0.495805
# min                0.000000    1.000000    0.000000        0.000000
# 25%                0.000000    1.000000    0.000000        0.000000
# 50%                0.000000    1.000000    1.000000        1.000000
# 75%                0.000000    1.000000    2.000000        1.000000
# max                1.000000    4.000000    4.000000        1.000000
#
#        Social smoker         Pet      Weight      Height  Body mass index  \
# count     736.000000  738.000000  739.000000  726.000000       709.000000
# mean        0.073370    0.746612   79.063599  172.152893        26.684062
# std         0.260919    1.319726   12.868630    6.081065         4.292819
# min         0.000000    0.000000   56.000000  163.000000        19.000000
# 25%         0.000000    0.000000   69.000000  169.000000        24.000000
# 50%         0.000000    0.000000   83.000000  170.000000        25.000000
# 75%         0.000000    1.000000   89.000000  172.000000        31.000000
# max         1.000000    8.000000  108.000000  196.000000        38.000000
#
#        Absenteeism time in hours
# count                 718.000000
# mean                    6.977716
# std                    13.476962
# min                     0.000000
# 25%                     2.000000
# 50%                     3.000000
# 75%                     8.000000
# max                   120.000000

# %%
# prints unique values for each features
print(df['Age'].unique())
len(df['Age'].unique())
# Out:
# [33. 50. 38. 39. 28. 36. 34. 37. 41. 47. 29. 48. 32. 27. 43. 40. 31. 30.
#  nan 49. 58. 46. 53.]
# [33. 50. 38. 39. 28. 36. 34. 37. 41. 47. 29. 48. 32. 27. 43. 40. 31. 30.
#  nan 49. 58. 46. 53.]
# 23
# 23

# %%
df.max() # prints maximum values of ALL the features 
df['Age'].max() # prints maximum values of Age features
df[['Age', 'Seasons']].max() # prints maximum values of Age and Seasons features
df[['Age', 'Seasons', 'Service time']].max() # prints maximum values of Age and Seasons features
# Out:
# Age             58.0
# Seasons          4.0
# Service time    29.0
# dtype: float64
# Age             58.0
# Seasons          4.0
# Service time    29.0
# dtype: float64

# %%
# investigate number of null values per features 
df.isnull().sum()
# Out:
# ID                                  0
# Reason for absence                  3
# Month of absence                    1
# Day of the week                     0
# Seasons                             0
# Transportation expense              7
# Distance from Residence to Work     3
# Service time                        3
# Age                                 3
# Work load Average/day              10
# Hit target                          6
# Disciplinary failure                6
# Education                          10
# Son                                 6
# Social drinker                      3
# Social smoker                       4
# Pet                                 2
# Weight                              1
# Height                             14
# Body mass index                    31
# Absenteeism time in hours          22
# dtype: int64
# ID                                  0
# Reason for absence                  3
# Month of absence                    1
# Day of the week                     0
# Seasons                             0
# Transportation expense              7
# Distance from Residence to Work     3
# Service time                        3
# Age                                 3
# Work load Average/day              10
# Hit target                          6
# Disciplinary failure                6
# Education                          10
# Son                                 6
# Social drinker                      3
# Social smoker                       4
# Pet                                 2
# Weight                              1
# Height                             14
# Body mass index                    31
# Absenteeism time in hours          22
# dtype: int64

# %%
# count the duplicate entries; not dropping
df.drop_duplicates()
#df.describe()
#df.dropna()
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0    11                26.0               7.0                3        1
# 1    36                 0.0               7.0                3        1
# 2     3                23.0               7.0                4        1
# 3     7                 7.0               7.0                5        1
# 4    11                23.0               7.0                5        1
# ..   ..                 ...               ...              ...      ...
# 735  11                14.0               7.0                3        1
# 736   1                11.0               7.0                3        1
# 737   4                 0.0               0.0                3        1
# 738   8                 0.0               0.0                4        2
# 739  35                 0.0               0.0                6        3
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# 0                     289.0                             36.0          13.0
# 1                     118.0                             13.0          18.0
# 2                     179.0                             51.0          18.0
# 3                     279.0                              5.0          14.0
# 4                     289.0                             36.0          13.0
# ..                      ...                              ...           ...
# 735                   289.0                             36.0          13.0
# 736                   235.0                             11.0          14.0
# 737                   118.0                             14.0          13.0
# 738                   231.0                             35.0          14.0
# 739                   179.0                             45.0          14.0
#
#       Age  Work load Average/day   Hit target  Disciplinary failure  \
# 0    33.0                239554.0        97.0                   0.0
# 1    50.0                239554.0        97.0                   1.0
# 2    38.0                239554.0        97.0                   0.0
# 3    39.0                239554.0        97.0                   0.0
# 4    33.0                239554.0        97.0                   0.0
# ..    ...                     ...         ...                   ...
# 735  33.0                264604.0        93.0                   0.0
# 736  37.0                264604.0        93.0                   0.0
# 737  40.0                271219.0        95.0                   0.0
# 738  39.0                271219.0        95.0                   0.0
# 739  53.0                271219.0        95.0                   0.0
#
#      Education  Son  Social drinker  Social smoker  Pet  Weight  Height  \
# 0          1.0  2.0             1.0            0.0  1.0    90.0   172.0
# 1          1.0  1.0             1.0            0.0  0.0    98.0   178.0
# 2          1.0  0.0             1.0            0.0  0.0    89.0   170.0
# 3          1.0  2.0             1.0            1.0  0.0    68.0   168.0
# 4          1.0  2.0             1.0            0.0  1.0    90.0   172.0
# ..         ...  ...             ...            ...  ...     ...     ...
# 735        1.0  2.0             1.0            0.0  1.0    90.0   172.0
# 736        3.0  1.0             0.0            0.0  1.0    88.0   172.0
# 737        1.0  1.0             1.0            0.0  8.0    98.0   170.0
# 738        1.0  2.0             1.0            0.0  2.0   100.0   170.0
# 739        1.0  1.0             0.0            0.0  1.0    77.0   175.0
#
#      Body mass index  Absenteeism time in hours
# 0               30.0                        4.0
# 1               31.0                        0.0
# 2               31.0                        2.0
# 3               24.0                        4.0
# 4               30.0                        2.0
# ..               ...                        ...
# 735             30.0                        8.0
# 736             29.0                        4.0
# 737             34.0                        0.0
# 738             35.0                        0.0
# 739             25.0                        0.0
#
# [715 rows x 21 columns]
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0    11                26.0               7.0                3        1
# 1    36                 0.0               7.0                3        1
# 2     3                23.0               7.0                4        1
# 3     7                 7.0               7.0                5        1
# 4    11                23.0               7.0                5        1
# ..   ..                 ...               ...              ...      ...
# 735  11                14.0               7.0                3        1
# 736   1                11.0               7.0                3        1
# 737   4                 0.0               0.0                3        1
# 738   8                 0.0               0.0                4        2
# 739  35                 0.0               0.0                6        3
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# 0                     289.0                             36.0          13.0
# 1                     118.0                             13.0          18.0
# 2                     179.0                             51.0          18.0
# 3                     279.0                              5.0          14.0
# 4                     289.0                             36.0          13.0
# ..                      ...                              ...           ...
# 735                   289.0                             36.0          13.0
# 736                   235.0                             11.0          14.0
# 737                   118.0                             14.0          13.0
# 738                   231.0                             35.0          14.0
# 739                   179.0                             45.0          14.0
#
#       Age  Work load Average/day   Hit target  Disciplinary failure  \
# 0    33.0                239554.0        97.0                   0.0
# 1    50.0                239554.0        97.0                   1.0
# 2    38.0                239554.0        97.0                   0.0
# 3    39.0                239554.0        97.0                   0.0
# 4    33.0                239554.0        97.0                   0.0
# ..    ...                     ...         ...                   ...
# 735  33.0                264604.0        93.0                   0.0
# 736  37.0                264604.0        93.0                   0.0
# 737  40.0                271219.0        95.0                   0.0
# 738  39.0                271219.0        95.0                   0.0
# 739  53.0                271219.0        95.0                   0.0
#
#      Education  Son  Social drinker  Social smoker  Pet  Weight  Height  \
# 0          1.0  2.0             1.0            0.0  1.0    90.0   172.0
# 1          1.0  1.0             1.0            0.0  0.0    98.0   178.0
# 2          1.0  0.0             1.0            0.0  0.0    89.0   170.0
# 3          1.0  2.0             1.0            1.0  0.0    68.0   168.0
# 4          1.0  2.0             1.0            0.0  1.0    90.0   172.0
# ..         ...  ...             ...            ...  ...     ...     ...
# 735        1.0  2.0             1.0            0.0  1.0    90.0   172.0
# 736        3.0  1.0             0.0            0.0  1.0    88.0   172.0
# 737        1.0  1.0             1.0            0.0  8.0    98.0   170.0
# 738        1.0  2.0             1.0            0.0  2.0   100.0   170.0
# 739        1.0  1.0             0.0            0.0  1.0    77.0   175.0
#
#      Body mass index  Absenteeism time in hours
# 0               30.0                        4.0
# 1               31.0                        0.0
# 2               31.0                        2.0
# 3               24.0                        4.0
# 4               30.0                        2.0
# ..               ...                        ...
# 735             30.0                        8.0
# 736             29.0                        4.0
# 737             34.0                        0.0
# 738             35.0                        0.0
# 739             25.0                        0.0
#
# [715 rows x 21 columns]

# %%
df.shape
# Out:
# (740, 21)
# (740, 21)

# %%
df.drop_duplicates(inplace = True)
# df = df.drop_duplicates()

# %%
df.shape
# Out:
# (715, 21)
# (715, 21)

# %%
df.describe()
# Out:
#                ID  Reason for absence  Month of absence  Day of the week  \
# count  715.000000          712.000000        714.000000       715.000000
# mean    18.296503           18.925562          6.387955         3.892308
# std     10.968323            8.460636          3.426556         1.422463
# min      1.000000            0.000000          0.000000         2.000000
# 25%     10.000000           13.000000          3.000000         3.000000
# 50%     18.000000           23.000000          6.000000         4.000000
# 75%     28.000000           26.000000          9.750000         5.000000
# max     36.000000           28.000000         12.000000         6.000000
#
#           Seasons  Transportation expense  Distance from Residence to Work  \
# count  715.000000              708.000000                       712.000000
# mean     2.549650              222.028249                        29.273876
# std      1.120841               67.686203                        14.770042
# min      1.000000              118.000000                         5.000000
# 25%      2.000000              179.000000                        16.000000
# 50%      3.000000              225.000000                        26.000000
# 75%      4.000000              260.000000                        49.000000
# max      4.000000              388.000000                        52.000000
#
#        Service time         Age  Work load Average/day   Hit target  \
# count    712.000000  712.000000              705.000000  709.000000
# mean      12.471910   36.446629           272006.039716   94.552891
# std        4.378929    6.548958            39308.085248    3.796978
# min        1.000000   27.000000           205917.000000   81.000000
# 25%        9.000000   31.000000           244387.000000   93.000000
# 50%       12.500000   37.000000           264604.000000   95.000000
# 75%       16.000000   40.000000           294217.000000   97.000000
# max       29.000000   58.000000           378884.000000  100.000000
#
#        Disciplinary failure   Education         Son  Social drinker  \
# count            709.000000  705.000000  709.000000      712.000000
# mean               0.055007    1.292199    1.049365        0.560393
# std                0.228155    0.671886    1.099096        0.496688
# min                0.000000    1.000000    0.000000        0.000000
# 25%                0.000000    1.000000    0.000000        0.000000
# 50%                0.000000    1.000000    1.000000        1.000000
# 75%                0.000000    1.000000    2.000000        1.000000
# max                1.000000    4.000000    4.000000        1.000000
#
#        Social smoker         Pet      Weight      Height  Body mass index  \
# count     711.000000  713.000000  714.000000  701.000000       684.000000
# mean        0.075949    0.768583   79.035014  172.226819        26.646199
# std         0.265104    1.334933   12.805489    6.174016         4.244776
# min         0.000000    0.000000   56.000000  163.000000        19.000000
# 25%         0.000000    0.000000   69.000000  169.000000        24.000000
# 50%         0.000000    0.000000   80.000000  171.000000        25.000000
# 75%         0.000000    1.000000   89.000000  172.000000        31.000000
# max         1.000000    8.000000  108.000000  196.000000        38.000000
#
#        Absenteeism time in hours
# count                 693.000000
# mean                    7.147186
# std                    13.687627
# min                     0.000000
# 25%                     2.000000
# 50%                     3.000000
# 75%                     8.000000
# max                   120.000000
#                ID  Reason for absence  Month of absence  Day of the week  \
# count  715.000000          712.000000        714.000000       715.000000
# mean    18.296503           18.925562          6.387955         3.892308
# std     10.968323            8.460636          3.426556         1.422463
# min      1.000000            0.000000          0.000000         2.000000
# 25%     10.000000           13.000000          3.000000         3.000000
# 50%     18.000000           23.000000          6.000000         4.000000
# 75%     28.000000           26.000000          9.750000         5.000000
# max     36.000000           28.000000         12.000000         6.000000
#
#           Seasons  Transportation expense  Distance from Residence to Work  \
# count  715.000000              708.000000                       712.000000
# mean     2.549650              222.028249                        29.273876
# std      1.120841               67.686203                        14.770042
# min      1.000000              118.000000                         5.000000
# 25%      2.000000              179.000000                        16.000000
# 50%      3.000000              225.000000                        26.000000
# 75%      4.000000              260.000000                        49.000000
# max      4.000000              388.000000                        52.000000
#
#        Service time         Age  Work load Average/day   Hit target  \
# count    712.000000  712.000000              705.000000  709.000000
# mean      12.471910   36.446629           272006.039716   94.552891
# std        4.378929    6.548958            39308.085248    3.796978
# min        1.000000   27.000000           205917.000000   81.000000
# 25%        9.000000   31.000000           244387.000000   93.000000
# 50%       12.500000   37.000000           264604.000000   95.000000
# 75%       16.000000   40.000000           294217.000000   97.000000
# max       29.000000   58.000000           378884.000000  100.000000
#
#        Disciplinary failure   Education         Son  Social drinker  \
# count            709.000000  705.000000  709.000000      712.000000
# mean               0.055007    1.292199    1.049365        0.560393
# std                0.228155    0.671886    1.099096        0.496688
# min                0.000000    1.000000    0.000000        0.000000
# 25%                0.000000    1.000000    0.000000        0.000000
# 50%                0.000000    1.000000    1.000000        1.000000
# 75%                0.000000    1.000000    2.000000        1.000000
# max                1.000000    4.000000    4.000000        1.000000
#
#        Social smoker         Pet      Weight      Height  Body mass index  \
# count     711.000000  713.000000  714.000000  701.000000       684.000000
# mean        0.075949    0.768583   79.035014  172.226819        26.646199
# std         0.265104    1.334933   12.805489    6.174016         4.244776
# min         0.000000    0.000000   56.000000  163.000000        19.000000
# 25%         0.000000    0.000000   69.000000  169.000000        24.000000
# 50%         0.000000    0.000000   80.000000  171.000000        25.000000
# 75%         0.000000    1.000000   89.000000  172.000000        31.000000
# max         1.000000    8.000000  108.000000  196.000000        38.000000
#
#        Absenteeism time in hours
# count                 693.000000
# mean                    7.147186
# std                    13.687627
# min                     0.000000
# 25%                     2.000000
# 50%                     3.000000
# 75%                     8.000000
# max                   120.000000

# %%
df.isnull().sum() # check how many missing values in the data
# Out:
# ID                                  0
# Reason for absence                  3
# Month of absence                    1
# Day of the week                     0
# Seasons                             0
# Transportation expense              7
# Distance from Residence to Work     3
# Service time                        3
# Age                                 3
# Work load Average/day              10
# Hit target                          6
# Disciplinary failure                6
# Education                          10
# Son                                 6
# Social drinker                      3
# Social smoker                       4
# Pet                                 2
# Weight                              1
# Height                             14
# Body mass index                    31
# Absenteeism time in hours          22
# dtype: int64
# ID                                  0
# Reason for absence                  3
# Month of absence                    1
# Day of the week                     0
# Seasons                             0
# Transportation expense              7
# Distance from Residence to Work     3
# Service time                        3
# Age                                 3
# Work load Average/day              10
# Hit target                          6
# Disciplinary failure                6
# Education                          10
# Son                                 6
# Social drinker                      3
# Social smoker                       4
# Pet                                 2
# Weight                              1
# Height                             14
# Body mass index                    31
# Absenteeism time in hours          22
# dtype: int64

# %%
# removing entire column
df_BMI_drop = df.drop(['Body mass index'],axis=1) # Drop specified labels from rows or columns
df_BMI_drop.isnull().sum()
# Out:
# ID                                  0
# Reason for absence                  3
# Month of absence                    1
# Day of the week                     0
# Seasons                             0
# Transportation expense              7
# Distance from Residence to Work     3
# Service time                        3
# Age                                 3
# Work load Average/day              10
# Hit target                          6
# Disciplinary failure                6
# Education                          10
# Son                                 6
# Social drinker                      3
# Social smoker                       4
# Pet                                 2
# Weight                              1
# Height                             14
# Absenteeism time in hours          22
# dtype: int64
# ID                                  0
# Reason for absence                  3
# Month of absence                    1
# Day of the week                     0
# Seasons                             0
# Transportation expense              7
# Distance from Residence to Work     3
# Service time                        3
# Age                                 3
# Work load Average/day              10
# Hit target                          6
# Disciplinary failure                6
# Education                          10
# Son                                 6
# Social drinker                      3
# Social smoker                       4
# Pet                                 2
# Weight                              1
# Height                             14
# Absenteeism time in hours          22
# dtype: int64

# %%
#Replace the missing value with '0' using 'fiilna' method
df_zero = df
df_zero['Body mass index'] = df['Body mass index'].fillna(0) 
df_zero['Body mass index'].isnull().sum()
# Out:
# 0
# 0

# %%
#Replace the missing values for numerical columns with mean: Mean imputation
df_median = df
df_median['Body mass index'] = df['Body mass index'].fillna(df['Body mass index'].median())
df_median.isnull().sum()
# train_df['Credit_History'] = train_df[‘Credit_History'].fillna(train_df['Credit_History'].mean())
# Out:
# ID                                  0
# Reason for absence                  3
# Month of absence                    1
# Day of the week                     0
# Seasons                             0
# Transportation expense              7
# Distance from Residence to Work     3
# Service time                        3
# Age                                 3
# Work load Average/day              10
# Hit target                          6
# Disciplinary failure                6
# Education                          10
# Son                                 6
# Social drinker                      3
# Social smoker                       4
# Pet                                 2
# Weight                              1
# Height                             14
# Body mass index                     0
# Absenteeism time in hours          22
# dtype: int64
# ID                                  0
# Reason for absence                  3
# Month of absence                    1
# Day of the week                     0
# Seasons                             0
# Transportation expense              7
# Distance from Residence to Work     3
# Service time                        3
# Age                                 3
# Work load Average/day              10
# Hit target                          6
# Disciplinary failure                6
# Education                          10
# Son                                 6
# Social drinker                      3
# Social smoker                       4
# Pet                                 2
# Weight                              1
# Height                             14
# Body mass index                     0
# Absenteeism time in hours          22
# dtype: int64

# %%
df_median.head(10)
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0  11                26.0               7.0                3        1
# 1  36                 0.0               7.0                3        1
# 2   3                23.0               7.0                4        1
# 3   7                 7.0               7.0                5        1
# 4  11                23.0               7.0                5        1
# 5   3                23.0               7.0                6        1
# 6  10                22.0               7.0                6        1
# 7  20                23.0               7.0                6        1
# 8  14                19.0               7.0                2        1
# 9   1                22.0               7.0                2        1
#
#    Transportation expense  Distance from Residence to Work  Service time  \
# 0                   289.0                             36.0          13.0
# 1                   118.0                             13.0          18.0
# 2                   179.0                             51.0          18.0
# 3                   279.0                              5.0          14.0
# 4                   289.0                             36.0          13.0
# 5                   179.0                             51.0          18.0
# 6                     NaN                             52.0           3.0
# 7                   260.0                             50.0          11.0
# 8                   155.0                             12.0          14.0
# 9                   235.0                             11.0          14.0
#
#     Age  Work load Average/day   Hit target  Disciplinary failure  Education  \
# 0  33.0                239554.0        97.0                   0.0        1.0
# 1  50.0                239554.0        97.0                   1.0        1.0
# 2  38.0                239554.0        97.0                   0.0        1.0
# 3  39.0                239554.0        97.0                   0.0        1.0
# 4  33.0                239554.0        97.0                   0.0        1.0
# 5  38.0                239554.0        97.0                   0.0        1.0
# 6  28.0                239554.0        97.0                   0.0        1.0
# 7  36.0                239554.0        97.0                   0.0        1.0
# 8  34.0                239554.0        97.0                   0.0        1.0
# 9  37.0                239554.0        97.0                   0.0        3.0
#
#    Son  Social drinker  Social smoker  Pet  Weight  Height  Body mass index  \
# 0  2.0             1.0            0.0  1.0    90.0   172.0             30.0
# 1  1.0             1.0            0.0  0.0    98.0   178.0             31.0
# 2  0.0             1.0            0.0  0.0    89.0   170.0             31.0
# 3  2.0             1.0            1.0  0.0    68.0   168.0             24.0
# 4  2.0             1.0            0.0  1.0    90.0   172.0             30.0
# 5  0.0             1.0            0.0  0.0    89.0   170.0             31.0
# 6  1.0             1.0            0.0  4.0    80.0   172.0             27.0
# 7  4.0             1.0            0.0  0.0    65.0   168.0             23.0
# 8  2.0             1.0            0.0  0.0    95.0   196.0             25.0
# 9  1.0             0.0            0.0  1.0    88.0   172.0             29.0
#
#    Absenteeism time in hours
# 0                        4.0
# 1                        0.0
# 2                        2.0
# 3                        4.0
# 4                        2.0
# 5                        NaN
# 6                        8.0
# 7                        4.0
# 8                       40.0
# 9                        8.0
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0  11                26.0               7.0                3        1
# 1  36                 0.0               7.0                3        1
# 2   3                23.0               7.0                4        1
# 3   7                 7.0               7.0                5        1
# 4  11                23.0               7.0                5        1
# 5   3                23.0               7.0                6        1
# 6  10                22.0               7.0                6        1
# 7  20                23.0               7.0                6        1
# 8  14                19.0               7.0                2        1
# 9   1                22.0               7.0                2        1
#
#    Transportation expense  Distance from Residence to Work  Service time  \
# 0                   289.0                             36.0          13.0
# 1                   118.0                             13.0          18.0
# 2                   179.0                             51.0          18.0
# 3                   279.0                              5.0          14.0
# 4                   289.0                             36.0          13.0
# 5                   179.0                             51.0          18.0
# 6                     NaN                             52.0           3.0
# 7                   260.0                             50.0          11.0
# 8                   155.0                             12.0          14.0
# 9                   235.0                             11.0          14.0
#
#     Age  Work load Average/day   Hit target  Disciplinary failure  Education  \
# 0  33.0                239554.0        97.0                   0.0        1.0
# 1  50.0                239554.0        97.0                   1.0        1.0
# 2  38.0                239554.0        97.0                   0.0        1.0
# 3  39.0                239554.0        97.0                   0.0        1.0
# 4  33.0                239554.0        97.0                   0.0        1.0
# 5  38.0                239554.0        97.0                   0.0        1.0
# 6  28.0                239554.0        97.0                   0.0        1.0
# 7  36.0                239554.0        97.0                   0.0        1.0
# 8  34.0                239554.0        97.0                   0.0        1.0
# 9  37.0                239554.0        97.0                   0.0        3.0
#
#    Son  Social drinker  Social smoker  Pet  Weight  Height  Body mass index  \
# 0  2.0             1.0            0.0  1.0    90.0   172.0             30.0
# 1  1.0             1.0            0.0  0.0    98.0   178.0             31.0
# 2  0.0             1.0            0.0  0.0    89.0   170.0             31.0
# 3  2.0             1.0            1.0  0.0    68.0   168.0             24.0
# 4  2.0             1.0            0.0  1.0    90.0   172.0             30.0
# 5  0.0             1.0            0.0  0.0    89.0   170.0             31.0
# 6  1.0             1.0            0.0  4.0    80.0   172.0             27.0
# 7  4.0             1.0            0.0  0.0    65.0   168.0             23.0
# 8  2.0             1.0            0.0  0.0    95.0   196.0             25.0
# 9  1.0             0.0            0.0  1.0    88.0   172.0             29.0
#
#    Absenteeism time in hours
# 0                        4.0
# 1                        0.0
# 2                        2.0
# 3                        4.0
# 4                        2.0
# 5                        NaN
# 6                        8.0
# 7                        4.0
# 8                       40.0
# 9                        8.0

# %%
df.describe()
df.dropna(inplace = True)

# %%
df.describe()
# Out:
#                ID  Reason for absence  Month of absence  Day of the week  \
# count  638.000000           638.00000        638.000000       638.000000
# mean    18.130094            18.92163          6.278997         3.855799
# std     10.974367             8.46176          3.340522         1.422368
# min      1.000000             0.00000          0.000000         2.000000
# 25%     10.000000            13.00000          3.000000         3.000000
# 50%     18.000000            23.00000          6.000000         4.000000
# 75%     28.000000            26.00000          9.000000         5.000000
# max     36.000000            28.00000         12.000000         6.000000
#
#           Seasons  Transportation expense  Distance from Residence to Work  \
# count  638.000000              638.000000                       638.000000
# mean     2.523511              221.918495                        29.194357
# std      1.104541               65.852647                        14.586391
# min      1.000000              118.000000                         5.000000
# 25%      2.000000              179.000000                        16.000000
# 50%      3.000000              225.000000                        26.000000
# 75%      3.000000              260.000000                        48.750000
# max      4.000000              388.000000                        52.000000
#
#        Service time         Age  Work load Average/day   Hit target  \
# count    638.000000  638.000000              638.000000  638.000000
# mean      12.594044   36.623824           271492.253918   94.695925
# std        4.333046    6.644330            39679.594393    3.747738
# min        1.000000   27.000000           205917.000000   81.000000
# 25%        9.000000   31.000000           241476.000000   93.000000
# 50%       13.000000   37.000000           264604.000000   95.000000
# 75%       16.000000   40.000000           284853.000000   98.000000
# max       29.000000   58.000000           378884.000000  100.000000
#
#        Disciplinary failure   Education         Son  Social drinker  \
# count            638.000000  638.000000  638.000000      638.000000
# mean               0.050157    1.297806    1.053292        0.564263
# std                0.218440    0.676375    1.085214        0.496242
# min                0.000000    1.000000    0.000000        0.000000
# 25%                0.000000    1.000000    0.000000        0.000000
# 50%                0.000000    1.000000    1.000000        1.000000
# 75%                0.000000    1.000000    2.000000        1.000000
# max                1.000000    4.000000    4.000000        1.000000
#
#        Social smoker         Pet      Weight      Height  Body mass index  \
# count     638.000000  638.000000  638.000000  638.000000       638.000000
# mean        0.078370    0.764890   79.199060  172.222571        25.727273
# std         0.268964    1.333504   12.837697    6.174642         6.606755
# min         0.000000    0.000000   56.000000  163.000000         0.000000
# 25%         0.000000    0.000000   69.000000  169.000000        23.000000
# 50%         0.000000    0.000000   83.000000  170.500000        25.000000
# 75%         0.000000    1.000000   89.000000  172.000000        31.000000
# max         1.000000    8.000000  108.000000  196.000000        38.000000
#
#        Absenteeism time in hours
# count                 638.000000
# mean                    7.191223
# std                    13.990166
# min                     0.000000
# 25%                     2.000000
# 50%                     3.000000
# 75%                     8.000000
# max                   120.000000
#                ID  Reason for absence  Month of absence  Day of the week  \
# count  638.000000           638.00000        638.000000       638.000000
# mean    18.130094            18.92163          6.278997         3.855799
# std     10.974367             8.46176          3.340522         1.422368
# min      1.000000             0.00000          0.000000         2.000000
# 25%     10.000000            13.00000          3.000000         3.000000
# 50%     18.000000            23.00000          6.000000         4.000000
# 75%     28.000000            26.00000          9.000000         5.000000
# max     36.000000            28.00000         12.000000         6.000000
#
#           Seasons  Transportation expense  Distance from Residence to Work  \
# count  638.000000              638.000000                       638.000000
# mean     2.523511              221.918495                        29.194357
# std      1.104541               65.852647                        14.586391
# min      1.000000              118.000000                         5.000000
# 25%      2.000000              179.000000                        16.000000
# 50%      3.000000              225.000000                        26.000000
# 75%      3.000000              260.000000                        48.750000
# max      4.000000              388.000000                        52.000000
#
#        Service time         Age  Work load Average/day   Hit target  \
# count    638.000000  638.000000              638.000000  638.000000
# mean      12.594044   36.623824           271492.253918   94.695925
# std        4.333046    6.644330            39679.594393    3.747738
# min        1.000000   27.000000           205917.000000   81.000000
# 25%        9.000000   31.000000           241476.000000   93.000000
# 50%       13.000000   37.000000           264604.000000   95.000000
# 75%       16.000000   40.000000           284853.000000   98.000000
# max       29.000000   58.000000           378884.000000  100.000000
#
#        Disciplinary failure   Education         Son  Social drinker  \
# count            638.000000  638.000000  638.000000      638.000000
# mean               0.050157    1.297806    1.053292        0.564263
# std                0.218440    0.676375    1.085214        0.496242
# min                0.000000    1.000000    0.000000        0.000000
# 25%                0.000000    1.000000    0.000000        0.000000
# 50%                0.000000    1.000000    1.000000        1.000000
# 75%                0.000000    1.000000    2.000000        1.000000
# max                1.000000    4.000000    4.000000        1.000000
#
#        Social smoker         Pet      Weight      Height  Body mass index  \
# count     638.000000  638.000000  638.000000  638.000000       638.000000
# mean        0.078370    0.764890   79.199060  172.222571        25.727273
# std         0.268964    1.333504   12.837697    6.174642         6.606755
# min         0.000000    0.000000   56.000000  163.000000         0.000000
# 25%         0.000000    0.000000   69.000000  169.000000        23.000000
# 50%         0.000000    0.000000   83.000000  170.500000        25.000000
# 75%         0.000000    1.000000   89.000000  172.000000        31.000000
# max         1.000000    8.000000  108.000000  196.000000        38.000000
#
#        Absenteeism time in hours
# count                 638.000000
# mean                    7.191223
# std                    13.990166
# min                     0.000000
# 25%                     2.000000
# 50%                     3.000000
# 75%                     8.000000
# max                   120.000000

# %%
# drop all rows with any NaN and NaT values
df1 = df.dropna() # Remove missing values
df1.describe()
df1.isnull().sum()
# Out:
# ID                                 0
# Reason for absence                 0
# Month of absence                   0
# Day of the week                    0
# Seasons                            0
# Transportation expense             0
# Distance from Residence to Work    0
# Service time                       0
# Age                                0
# Work load Average/day              0
# Hit target                         0
# Disciplinary failure               0
# Education                          0
# Son                                0
# Social drinker                     0
# Social smoker                      0
# Pet                                0
# Weight                             0
# Height                             0
# Body mass index                    0
# Absenteeism time in hours          0
# dtype: int64
# ID                                 0
# Reason for absence                 0
# Month of absence                   0
# Day of the week                    0
# Seasons                            0
# Transportation expense             0
# Distance from Residence to Work    0
# Service time                       0
# Age                                0
# Work load Average/day              0
# Hit target                         0
# Disciplinary failure               0
# Education                          0
# Son                                0
# Social drinker                     0
# Social smoker                      0
# Pet                                0
# Weight                             0
# Height                             0
# Body mass index                    0
# Absenteeism time in hours          0
# dtype: int64

# %%
df.Son.value_counts() # Return a Series containing counts of unique values in descending order
# Out:
# 0.0    242
# 1.0    202
# 2.0    147
# 4.0     35
# 3.0     12
# Name: Son, dtype: int64
# 0.0    242
# 1.0    202
# 2.0    147
# 4.0     35
# 3.0     12
# Name: Son, dtype: int64

# %%
df.describe()
# Out:
#                ID  Reason for absence  Month of absence  Day of the week  \
# count  638.000000           638.00000        638.000000       638.000000
# mean    18.130094            18.92163          6.278997         3.855799
# std     10.974367             8.46176          3.340522         1.422368
# min      1.000000             0.00000          0.000000         2.000000
# 25%     10.000000            13.00000          3.000000         3.000000
# 50%     18.000000            23.00000          6.000000         4.000000
# 75%     28.000000            26.00000          9.000000         5.000000
# max     36.000000            28.00000         12.000000         6.000000
#
#           Seasons  Transportation expense  Distance from Residence to Work  \
# count  638.000000              638.000000                       638.000000
# mean     2.523511              221.918495                        29.194357
# std      1.104541               65.852647                        14.586391
# min      1.000000              118.000000                         5.000000
# 25%      2.000000              179.000000                        16.000000
# 50%      3.000000              225.000000                        26.000000
# 75%      3.000000              260.000000                        48.750000
# max      4.000000              388.000000                        52.000000
#
#        Service time         Age  Work load Average/day   Hit target  \
# count    638.000000  638.000000              638.000000  638.000000
# mean      12.594044   36.623824           271492.253918   94.695925
# std        4.333046    6.644330            39679.594393    3.747738
# min        1.000000   27.000000           205917.000000   81.000000
# 25%        9.000000   31.000000           241476.000000   93.000000
# 50%       13.000000   37.000000           264604.000000   95.000000
# 75%       16.000000   40.000000           284853.000000   98.000000
# max       29.000000   58.000000           378884.000000  100.000000
#
#        Disciplinary failure   Education         Son  Social drinker  \
# count            638.000000  638.000000  638.000000      638.000000
# mean               0.050157    1.297806    1.053292        0.564263
# std                0.218440    0.676375    1.085214        0.496242
# min                0.000000    1.000000    0.000000        0.000000
# 25%                0.000000    1.000000    0.000000        0.000000
# 50%                0.000000    1.000000    1.000000        1.000000
# 75%                0.000000    1.000000    2.000000        1.000000
# max                1.000000    4.000000    4.000000        1.000000
#
#        Social smoker         Pet      Weight      Height  Body mass index  \
# count     638.000000  638.000000  638.000000  638.000000       638.000000
# mean        0.078370    0.764890   79.199060  172.222571        25.727273
# std         0.268964    1.333504   12.837697    6.174642         6.606755
# min         0.000000    0.000000   56.000000  163.000000         0.000000
# 25%         0.000000    0.000000   69.000000  169.000000        23.000000
# 50%         0.000000    0.000000   83.000000  170.500000        25.000000
# 75%         0.000000    1.000000   89.000000  172.000000        31.000000
# max         1.000000    8.000000  108.000000  196.000000        38.000000
#
#        Absenteeism time in hours
# count                 638.000000
# mean                    7.191223
# std                    13.990166
# min                     0.000000
# 25%                     2.000000
# 50%                     3.000000
# 75%                     8.000000
# max                   120.000000
#                ID  Reason for absence  Month of absence  Day of the week  \
# count  638.000000           638.00000        638.000000       638.000000
# mean    18.130094            18.92163          6.278997         3.855799
# std     10.974367             8.46176          3.340522         1.422368
# min      1.000000             0.00000          0.000000         2.000000
# 25%     10.000000            13.00000          3.000000         3.000000
# 50%     18.000000            23.00000          6.000000         4.000000
# 75%     28.000000            26.00000          9.000000         5.000000
# max     36.000000            28.00000         12.000000         6.000000
#
#           Seasons  Transportation expense  Distance from Residence to Work  \
# count  638.000000              638.000000                       638.000000
# mean     2.523511              221.918495                        29.194357
# std      1.104541               65.852647                        14.586391
# min      1.000000              118.000000                         5.000000
# 25%      2.000000              179.000000                        16.000000
# 50%      3.000000              225.000000                        26.000000
# 75%      3.000000              260.000000                        48.750000
# max      4.000000              388.000000                        52.000000
#
#        Service time         Age  Work load Average/day   Hit target  \
# count    638.000000  638.000000              638.000000  638.000000
# mean      12.594044   36.623824           271492.253918   94.695925
# std        4.333046    6.644330            39679.594393    3.747738
# min        1.000000   27.000000           205917.000000   81.000000
# 25%        9.000000   31.000000           241476.000000   93.000000
# 50%       13.000000   37.000000           264604.000000   95.000000
# 75%       16.000000   40.000000           284853.000000   98.000000
# max       29.000000   58.000000           378884.000000  100.000000
#
#        Disciplinary failure   Education         Son  Social drinker  \
# count            638.000000  638.000000  638.000000      638.000000
# mean               0.050157    1.297806    1.053292        0.564263
# std                0.218440    0.676375    1.085214        0.496242
# min                0.000000    1.000000    0.000000        0.000000
# 25%                0.000000    1.000000    0.000000        0.000000
# 50%                0.000000    1.000000    1.000000        1.000000
# 75%                0.000000    1.000000    2.000000        1.000000
# max                1.000000    4.000000    4.000000        1.000000
#
#        Social smoker         Pet      Weight      Height  Body mass index  \
# count     638.000000  638.000000  638.000000  638.000000       638.000000
# mean        0.078370    0.764890   79.199060  172.222571        25.727273
# std         0.268964    1.333504   12.837697    6.174642         6.606755
# min         0.000000    0.000000   56.000000  163.000000         0.000000
# 25%         0.000000    0.000000   69.000000  169.000000        23.000000
# 50%         0.000000    0.000000   83.000000  170.500000        25.000000
# 75%         0.000000    1.000000   89.000000  172.000000        31.000000
# max         1.000000    8.000000  108.000000  196.000000        38.000000
#
#        Absenteeism time in hours
# count                 638.000000
# mean                    7.191223
# std                    13.990166
# min                     0.000000
# 25%                     2.000000
# 50%                     3.000000
# 75%                     8.000000
# max                   120.000000

# %%
from matplotlib import pyplot as plt 
import seaborn as sns

# %%
print(df.columns.tolist()) # convert a given array to an ordinary list
# Out:
# ['ID', 'Reason for absence', 'Month of absence', 'Day of the week', 'Seasons', 'Transportation expense', 'Distance from Residence to Work', 'Service time', 'Age', 'Work load Average/day ', 'Hit target', 'Disciplinary failure', 'Education', 'Son', 'Social drinker', 'Social smoker', 'Pet', 'Weight', 'Height', 'Body mass index', 'Absenteeism time in hours']
# ['ID', 'Reason for absence', 'Month of absence', 'Day of the week', 'Seasons', 'Transportation expense', 'Distance from Residence to Work', 'Service time', 'Age', 'Work load Average/day ', 'Hit target', 'Disciplinary failure', 'Education', 'Son', 'Social drinker', 'Social smoker', 'Pet', 'Weight', 'Height', 'Body mass index', 'Absenteeism time in hours']

# %%
#Let's see how the transortation expense varies with distance from residence to work
plt.figure(figsize = (8,8))
plt.scatter(x = 'Distance from Residence to Work', y = 'Transportation expense', data = df)
# scatter plot with pyplot
plt.xlabel('Distance from residence to work')
plt.ylabel('Transportation Expense')
plt.title('Scatterplot of transportation expense against distance from residence to work');

# %%
#plt.figure(figsize = (8,8))
sns.scatterplot(x = 'Distance from Residence to Work', y = 'Transportation expense', data = df);
# scatter plot with Seaborn

# %%
#plt.figure(figsize = (8,8))
sns.scatterplot(x = 'Distance from Residence to Work', y = 'Transportation expense', hue = 'Disciplinary failure', data = df);
#plt.axhline(y=222, color='r', linestyle='-');

# %%
df['Transportation expense'].describe()
# Out:
# count    638.000000
# mean     221.918495
# std       65.852647
# min      118.000000
# 25%      179.000000
# 50%      225.000000
# 75%      260.000000
# max      388.000000
# Name: Transportation expense, dtype: float64
# count    638.000000
# mean     221.918495
# std       65.852647
# min      118.000000
# 25%      179.000000
# 50%      225.000000
# 75%      260.000000
# max      388.000000
# Name: Transportation expense, dtype: float64

# %% [markdown]
# Example Gallery
# https://seaborn.pydata.org/examples/index.html

# %% [markdown]
# # Box and Whisker Plots: Indication of how the values in the data are spread out
# ![Box-Plot-and-Whisker-Plot-1.png](attachment:Box-Plot-and-Whisker-Plot-1.png)

# %%
import random
colorlist = ['red', 'yellow', 'orange', 'purple', 'blue']
sns.boxplot(x = 'Distance from Residence to Work', data = df, color = random.choice(colorlist)); # horizontal box plot

# %%
sns.boxplot(y = 'Distance from Residence to Work', data = df); # vertical box plot

# %%
for i in df.columns:
    plt.figure()
    sns.boxplot(x=i, data = df)
# Out:
# C:\Users\NSU\AppData\Local\Temp\ipykernel_7580\1638789516.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# C:\Users\NSU\AppData\Local\Temp\ipykernel_7580\1638789516.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()

# %%
for i in df.columns:
    plt.figure(figsize=(6,6))
    sns.boxplot(y=i, x = 'Disciplinary failure', data = df)
# Out:
# C:\Users\NSU\AppData\Local\Temp\ipykernel_7580\2179366589.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(6,6))
# C:\Users\NSU\AppData\Local\Temp\ipykernel_7580\2179366589.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(6,6))
